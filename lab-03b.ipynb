# %%
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
import librosa

# %% [markdown]
# **Load and convert the speech waveform to mono**

# %%
file_path="dataset/LJSpeech-1.1/wavs/LJ001-0001.wav"
waveform, sample_rate = torchaudio.load(file_path)
waveform = waveform.mean(dim=0).numpy()

# %% [markdown]
# **Compute STFT**

# %%
stft_result=librosa.stft(waveform, n_fft=1024, hop_length=256)
spectrogram=librosa.amplitude_to_db(np.abs(stft_result))

# %% [markdown]
# **Plotting the time domain representation of the signal and the STFT spectrogram**

# %%
plt.figure(figsize=(12, 8))
plt.subplot(3, 1, 1)
plt.plot(np.linspace(0, len(waveform) / sample_rate, len(waveform)), waveform)
plt.title("Time-Domain Representation of Speech Signal")
plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")

plt.subplot(3, 1, 2)
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=256, x_axis='time', y_axis='log')
plt.title("STFT Spectrogram")
plt.colorbar(label="Decibels (dB)")

plt.tight_layout()
plt.show()
