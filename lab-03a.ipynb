# %%
# !pip install torchaudio
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchaudio in /home/adithya/.local/lib/python3.13/site-packages (2.6.0)
# Requirement already satisfied: torch==2.6.0 in /home/adithya/.local/lib/python3.13/site-packages (from torchaudio) (2.6.0)
# Requirement already satisfied: filelock in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (4.12.2)
# Requirement already satisfied: networkx in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in /usr/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (3.2.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (69.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/adithya/.local/lib/python3.13/site-packages (from torch==2.6.0->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/adithya/.local/lib/python3.13/site-packages (from sympy==1.13.1->torch==2.6.0->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib64/python3.13/site-packages (from jinja2->torch==2.6.0->torchaudio) (2.1.5)

# %% [markdown]
# **Load and convert speech waveform to mono**

# %%
file_path="dataset/LJSpeech-1.1/wavs/LJ001-0001.wav"
waveform, sample_rate = torchaudio.load(file_path)
waveform = waveform.mean(dim=0).numpy()

# %% [markdown]
# **Computing FFT and the magnitude spectrum**

# %%
fft_result = np.fft.fft(waveform)
frequencies = np.fft.fftfreq(len(fft_result), d=1/sample_rate)
magnitude = np.abs(fft_result)

# %% [markdown]
# **Plotting the time-domain and frequency-domain representations**

# %%
plt.figure(figsize=(10, 4))

plt.subplot(2, 1, 1)
plt.plot(waveform)
plt.title("Time-Domain Signal")
plt.xlabel("Samples")
plt.ylabel("Amplitude")

plt.subplot(2, 1, 2)
plt.plot(frequencies[:len(frequencies)//2], magnitude[:len(magnitude)//2])
plt.title("Frequency Spectrum")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")

plt.tight_layout()
plt.show()
